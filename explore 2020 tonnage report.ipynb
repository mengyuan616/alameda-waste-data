# %%
import pandas as pd
# Out:
# /Users/KaylaDong/.pyenv/versions/3.8.5/envs/ca-waste-data-3.8.5/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
report_2020 = pd.read_excel('raw_data/LandfillSummaryTonnage - 2020.xlsx', skiprows=4)

# %% [markdown]
# `NaN` - Not a Number

# %%
report_2020
# Out:
#              County  Unnamed: 1  1st Quarter  2nd Quarter  3rd Quarter  \
# 0           Alameda         NaN       296675       271586     307672.0
# 1             Butte         NaN        51657        39408      44225.0
# 2         Calaveras         NaN         6695         9181          0.0
# 3            Colusa         NaN           68           84        130.0
# 4      Contra Costa         NaN       193183       185661     203079.0
# 5         El Dorado         NaN            0            0        318.0
# 6            Fresno         NaN       182617       176649     189898.0
# 7             Glenn         NaN            0            0          0.0
# 8          Imperial         NaN        77872        74727      50544.0
# 9              Inyo         NaN         5459         6236       6619.0
# 10             Kern         NaN       501238       431162     412535.0
# 11            Kings         NaN        38703        80086      87868.0
# ...
