# %%
import pandas as pd
# Out:
# /Users/KaylaDong/.pyenv/versions/3.8.5/envs/ca-waste-data-3.8.5/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
data = pd.DataFrame()

# %%
for num in range(1, 59): 
    
    report = pd.read_excel(f'raw_data/commercial_sum/BusinessGroupsForAMaterial - { num }.xlsx')
    report.rename(columns = {'Jurisdiction(s)':'Jurisdiction'}, inplace = True)
    data = data.append(report, ignore_index = True)

# %%
data
# Out:
#                                         Business Group          Jurisdiction  \
# 0      Services - Professional, Technical, & Financial  Alameda (Countywide)
# 1                                          Multifamily  Alameda (Countywide)
# 2    Services - Management, Administrative, Support...  Alameda (Countywide)
# 3                         Durable Wholesale & Trucking  Alameda (Countywide)
# 4                                          Restaurants  Alameda (Countywide)
# ..                                                 ...                   ...
# 981                  Arts, Entertainment, & Recreation     Yuba (Countywide)
# 982        Manufacturing - Food & Nondurable Wholesale     Yuba (Countywide)
# 983                       Services - Repair & Personal     Yuba (Countywide)
# 984                                   Hotels & Lodging     Yuba (Countywide)
# 985                Manufacturing -Electronic Equipment     Yuba (Countywide)
#
#           Material Type  Employee Count  Occupied Multifamily Units  \
# 0    All Material Types           98439                     0.00000
# 1    All Material Types               0                160357.91001
# 2    All Material Types           96107                     0.00000
# 3    All Material Types           36037                     0.00000
# 4    All Material Types           49389                     0.00000
# ..                  ...             ...                         ...
# 981  All Material Types             206                     0.00000
# 982  All Material Types             173                     0.00000
# 983  All Material Types             155                     0.00000
# 984  All Material Types               0                     0.00000
# 985  All Material Types               0                     0.00000
#
#      TPEPY Disposed  Tons Disposed  Percent of Disposal  \
# 0          1.610888  158574.204398             0.227008
# 1          0.000000  118579.370086             0.169753
# 2          0.600536   57715.752588             0.082623
# 3          0.571757   20604.424013             0.029496
# 4          1.571854   77632.313153             0.111135
# ..              ...            ...                  ...
# 981        1.941197     399.886662             0.029150
# 982        1.231006     212.964044             0.015524
# 983        0.850323     131.800013             0.009608
# 984        1.404361       0.000000             0.000000
# 985        0.312870       0.000000             0.000000
#
#      TPEPY Curbside Recycle  Tons Curbside Recycle  \
# 0                  0.297146           29250.800195
# 1                  0.000000           21030.136053
# 2                  0.089525            8603.983540
# 3                  0.164248            5919.009007
# 4                  0.178756            8828.586615
# ..                      ...                    ...
# 981                0.116318              23.961445
# 982                0.045582               7.885669
# 983                0.130581              20.240091
# 984                0.189157               0.000000
# 985                0.072246               0.000000
#
#      Percent of Curbside Recycle  TPEPY Curbside Organics  \
# 0                       0.301777                 0.077511
# 1                       0.216965                 0.000000
# 2                       0.088766                 0.476187
# 3                       0.061066                 0.000000
# 4                       0.091083                 0.115726
# ..                           ...                      ...
# 981                     0.013385                 0.018335
# 982                     0.004405                 0.011645
# 983                     0.011307                 0.211809
# 984                     0.000000                 0.012617
# 985                     0.000000                 0.000000
#
#      Tons Curbside Organics  Percent of Curbside Organics  \
# 0               7630.105415                      0.116512
# 1                583.319406                      0.008907
# 2              45764.950323                      0.698833
# 3                  0.000000                      0.000000
# 4               5715.585920                      0.087277
# ..                      ...                           ...
# 981                3.777053                      0.004540
# 982                2.014625                      0.002421
# 983               32.830431                      0.039458
# 984                0.000000                      0.000000
# 985                0.000000                      0.000000
#
#      TPEPY Other Diversion  Tons Other Diversion  Percent of Other Diversion  \
# 0                 0.039431           3881.509475                    0.016984
# 1                 0.000000              0.000000                    0.000000
# 2                 0.014120           1357.076197                    0.005938
# 3                 2.173639          78331.416709                    0.342745
# 4                 0.055625           2747.274819                    0.012021
# ..                     ...                   ...                         ...
# 981               0.225725             46.499334                    0.011334
# 982               0.497754             86.111525                    0.020990
# 983               0.165689             25.681730                    0.006260
# 984               0.158630              0.000000                    0.000000
# 985               0.360058              0.000000                    0.000000
#
#      TPEPY Total Generation  Tons Total Generation  \
# 0                  2.024976          199336.619483
# 1                  0.000000          140192.825545
# 2                  1.180369          113441.762649
# 3                  2.909644          104854.849729
# 4                  1.921962           94923.760508
# ..                      ...                    ...
# 981                2.301575             474.124495
# 982                1.785988             308.975863
# 983                1.358402             210.552265
# 984                1.764766               0.000000
# 985                0.745174               0.000000
#
#      Percent of Total Generation
# 0                       0.182962
# 1                       0.128677
# 2                       0.104123
# 3                       0.096242
# 4                       0.087126
# ..                           ...
# 981                     0.023193
# 982                     0.015114
# 983                     0.010299
# 984                     0.000000
# 985                     0.000000
#
# [986 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Business Group                986 non-null    object
#  1   Jurisdiction                  986 non-null    object
#  2   Material Type                 986 non-null    object
#  3   Employee Count                986 non-null    int64
#  4   Occupied Multifamily Units    986 non-null    float64
#  5   TPEPY Disposed                986 non-null    float64
#  6   Tons Disposed                 986 non-null    float64
#  7   Percent of Disposal           986 non-null    float64
#  8   TPEPY Curbside Recycle        986 non-null    float64
#  9   Tons Curbside Recycle         986 non-null    float64
#  10  Percent of Curbside Recycle   986 non-null    float64
#  11  TPEPY Curbside Organics       986 non-null    float64
#  12  Tons Curbside Organics        986 non-null    float64
#  13  Percent of Curbside Organics  986 non-null    float64
#  14  TPEPY Other Diversion         986 non-null    float64
#  15  Tons Other Diversion          986 non-null    float64
#  16  Percent of Other Diversion    986 non-null    float64
#  17  TPEPY Total Generation        986 non-null    float64
#  18  Tons Total Generation         986 non-null    float64
#  19  Percent of Total Generation   986 non-null    float64
# dtypes: float64(16), int64(1), object(3)
# memory usage: 154.2+ KB
