# %%
import pandas as pd

# %%
data = pd.DataFrame()

# %%
for num in range(1, 59): 
    
    report = pd.read_excel(f'raw_data/residential_sum/ResidentialStreamsExport - { num }.xlsx')
    report.rename(columns = {'Jurisdiction(s)':'Jurisdiction'}, inplace = True)
    data = data.append(report, ignore_index = True)

# %%
data
# Out:
#       Material Category                        Material Type  \
# 0                 Paper        Uncoated Corrugated Cardboard
# 1                 Paper                           Paper Bags
# 2                 Paper                            Newspaper
# 3                 Paper                   White Ledger Paper
# 4                 Paper                   Other Office Paper
# ...                 ...                                  ...
# 15713     Special Waste                Treated Medical Waste
# 15714     Special Waste                          Bulky Items
# 15715     Special Waste                                Tires
# 15716     Special Waste  Remainder / Composite Special Waste
# 15717     Mixed Residue                        Mixed Residue
#
#                Jurisdiction  Single Family Tons  \
# 0      Alameda (Countywide)                1917
# 1      Alameda (Countywide)                 898
# 2      Alameda (Countywide)                2078
# 3      Alameda (Countywide)                 531
# 4      Alameda (Countywide)                1368
# ...                     ...                 ...
# 15713     Yuba (Countywide)                   0
# 15714     Yuba (Countywide)                   7
# 15715     Yuba (Countywide)                  68
# 15716     Yuba (Countywide)                  13
# 15717     Yuba (Countywide)                 822
#
#        Regional Single Family Composition  Multi Family Tons  \
# 0                                0.006688               4231
# 1                                0.003132                625
# 2                                0.007250               5506
# 3                                0.001854                627
# 4                                0.004775                698
# ...                                   ...                ...
# 15713                            0.000000                 26
# 15714                            0.000466                 99
# 15715                            0.004516                  0
# 15716                            0.000883                  1
# 15717                            0.054388                121
#
#        Statewide Multi Family Composition  Total Residential Tons  \
# 0                                0.035679                    6147
# 1                                0.005275                    1523
# 2                                0.046431                    7583
# 3                                0.005287                    1158
# 4                                0.005888                    2067
# ...                                   ...                     ...
# 15713                            0.007386                      26
# 15714                            0.028140                     106
# 15715                            0.000000                      68
# 15716                            0.000202                      14
# 15717                            0.034470                     943
#
#        Total Residential Composition
# 0                           0.015173
# 1                           0.003759
# 2                           0.018717
# 3                           0.002859
# 4                           0.005101
# ...                              ...
# 15713                       0.001394
# 15714                       0.005691
# 15715                       0.003663
# 15716                       0.000755
# 15717                       0.050627
#
# [15718 rows x 9 columns]

# %%
data[data['Jurisdiction'] == 'Alameda (Countywide)']
# Out:
#    Material Category                        Material Type  \
# 0              Paper        Uncoated Corrugated Cardboard
# 1              Paper                           Paper Bags
# 2              Paper                            Newspaper
# 3              Paper                   White Ledger Paper
# 4              Paper                   Other Office Paper
# ..               ...                                  ...
# 63     Special Waste                Treated Medical Waste
# 64     Special Waste                          Bulky Items
# 65     Special Waste                                Tires
# 66     Special Waste  Remainder / Composite Special Waste
# 67     Mixed Residue                        Mixed Residue
#
#             Jurisdiction  Single Family Tons  \
# 0   Alameda (Countywide)                1917
# 1   Alameda (Countywide)                 898
# 2   Alameda (Countywide)                2078
# 3   Alameda (Countywide)                 531
# 4   Alameda (Countywide)                1368
# ..                   ...                 ...
# 63  Alameda (Countywide)                   0
# 64  Alameda (Countywide)               13431
# 65  Alameda (Countywide)                  81
# 66  Alameda (Countywide)                 928
# 67  Alameda (Countywide)               22272
#
#     Regional Single Family Composition  Multi Family Tons  \
# 0                             0.006688               4231
# 1                             0.003132                625
# 2                             0.007250               5506
# 3                             0.001854                627
# 4                             0.004775                698
# ..                                 ...                ...
# 63                            0.000000                876
# 64                            0.046868               3337
# 65                            0.000282                  0
# 66                            0.003237                 24
# 67                            0.077719               4087
#
#     Statewide Multi Family Composition  Total Residential Tons  \
# 0                             0.035679                    6147
# 1                             0.005275                    1523
# 2                             0.046431                    7583
# 3                             0.005287                    1158
# 4                             0.005888                    2067
# ..                                 ...                     ...
# 63                            0.007386                     876
# 64                            0.028140                   16768
# 65                            0.000000                      81
# 66                            0.000202                     952
# 67                            0.034470                   26359
#
#     Total Residential Composition
# 0                        0.015173
# 1                        0.003759
# 2                        0.018717
# 3                        0.002859
# 4                        0.005101
# ..                            ...
# 63                       0.002162
# 64                       0.041387
# 65                       0.000200
# 66                       0.002349
# 67                       0.065061
#
# [68 rows x 9 columns]
