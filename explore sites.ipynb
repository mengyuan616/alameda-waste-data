# %%
import pandas as pd
# Out:
# /Users/KaylaDong/.pyenv/versions/3.8.5/envs/ca-waste-data-3.8.5/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
sites = pd.read_excel('raw_data/Sites.xlsx')
sites
# Out:
#      SWIS Number                                  Site Name  Point of Contact  \
# 0      01-AA-0006            Davis Street Sanitary Landfill     Sabra Ambrose
# 1      01-AA-0014                   Therm-Tec Of California   Alyssa Williams
# 2      01-AA-0273               Marciel Ranch Landspreading     Sabra Ambrose
# 3      01-AC-0029  Cty of Berk Solid Waste Mgmt Center & TS         Lily Tieu
# 4      01-CR-0005                  Old West Winton Landfill     Sabra Ambrose
# ...           ...                                       ...               ...
# 5639   19-AR-1273                               GAIACA DTLA  Benjamin Escotto
# 5640   13-AA-0121                       Salton City Compost        Gina Weber
# 5641   35-AA-0034        John Smith Road Landfill Direct TS       Eric Tanner
# 5642   54-AA-0068  WC Wood Industries Company Composting Ag      Joy Isaacson
# 5643   24-AA-0045                               Seth Rossow     Harprit Mattu
#
# ...
